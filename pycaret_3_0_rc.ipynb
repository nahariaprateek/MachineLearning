# %% [markdown]
# <a href="https://colab.research.google.com/github/nahariaprateek/MachineLearning/blob/main/pycaret_3_0_rc.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install --pre pycaret

# %%
from pycaret.datasets import get_data
data = get_data('juice')
# Out:
#    Id Purchase  WeekofPurchase  StoreID  PriceCH  PriceMM  DiscCH  DiscMM  \
# 0   1       CH             237        1     1.75     1.99    0.00     0.0
# 1   2       CH             239        1     1.75     1.99    0.00     0.3
# 2   3       CH             245        1     1.86     2.09    0.17     0.0
# 3   4       MM             227        1     1.69     1.69    0.00     0.0
# 4   5       CH             228        7     1.69     1.69    0.00     0.0
#
#    SpecialCH  SpecialMM   LoyalCH  SalePriceMM  SalePriceCH  PriceDiff Store7  \
# 0          0          0  0.500000         1.99         1.75       0.24     No
# 1          0          1  0.600000         1.69         1.75      -0.06     No
# 2          0          0  0.680000         2.09         1.69       0.40     No
# 3          0          0  0.400000         1.69         1.69       0.00     No
# 4          0          0  0.956535         1.69         1.69       0.00    Yes
#
#    PctDiscMM  PctDiscCH  ListPriceDiff  STORE
# ...

# %%
from pycaret.classification import *
s = setup(data, target = 'Purchase')
# Out:
# <style type="text/css">
# #T_3d855_row11_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_3d855_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Description</th>
#       <th class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3d855_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3d855_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_3d855_row0_col1" class="data row0 col1" >5306</td>
#     </tr>
#     <tr>
#       <th id="T_3d855_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_3d855_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_3d855_row1_col1" class="data row1 col1" >Purchase</td>
#     </tr>
#     <tr>
#       <th id="T_3d855_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
best = compare_models()
# Out:
# <style type="text/css">
# #T_ff4fe_ th {
#   text-align: left;
# }
# ...

# %%
plot_model(best)

# %%
evaluate_model(best)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
from pycaret.classification import ClassificationExperiment
exp1 = ClassificationExperiment()

# %%
exp1.setup(data, target = 'Purchase')
# Out:
# <style type="text/css">
# #T_029e1_row11_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_029e1_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Description</th>
#       <th class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_029e1_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_029e1_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_029e1_row0_col1" class="data row0 col1" >4129</td>
#     </tr>
#     <tr>
#       <th id="T_029e1_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_029e1_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_029e1_row1_col1" class="data row1 col1" >Purchase</td>
#     </tr>
#     <tr>
#       <th id="T_029e1_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
dir(exp1)
# Out:
# ['USI',
#  'X',
#  'X_test',
#  'X_test_transformed',
#  'X_train',
#  'X_train_transformed',
#  'X_transformed',
#  '_ClassificationExperiment__is_multiclass',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_add_custom_pipeline',
#  '_all_metrics',
#  '_all_models',
#  '_all_models_internal',
#  '_available_plots',
#  '_balance',
#  '_bin_numerical_features',
#  '_calculate_metrics',
#  '_check_enviroment',
#  '_check_setup_ran',
#  '_choose_better',
#  '_convert_log_experiment',
#  '_create_app_predict_kwargs',
#  '_create_model',
#  '_create_model_with_cv',
#  '_create_model_without_cv',
# ...

# %%
exp1.compare_models()
# Out:
# <style type="text/css">
# #T_1b56b_ th {
#   text-align: left;
# }
# ...
